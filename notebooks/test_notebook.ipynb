# %%
print('hai from notebook')
# Out:
# hai from notebook

# %%
import googleapiclient.discovery
import pandas as pd

# Replace with your YouTube Data API v3 API key
API_KEY = "AIzaSyBgFY8OEiMSK-sq8Odr1yu2_T7v06du2fM"

# Define the channel ID
# CHANNEL_ID = "UCduIoIMfD8tT3KoU0-zBRgQ"
CHANNEL_ID ="UC88fRYqlcl9g4yhYErIm1Gw"


def playlist_details(API_KEY, CHANNEL_ID):
        # Define the YouTube service object
    youtube = googleapiclient.discovery.build(
        "youtube", "v3", developerKey=API_KEY
    )

    # Define the request parameters
    request = youtube.playlists().list(
        part="snippet",
        channelId=CHANNEL_ID,
        maxResults=500  # Adjust this parameter to retrieve a desired number of playlists
    )

    # Execute the request and get the response
    response = request.execute()
    # pprint.pprint(response)
    # Creating a dictionary for storing the playlist details
    playlist_dict=dict()
    #Setting the structure of the dictionary 
    playlist_dict['playlist_id']=list()
    playlist_dict['channel_id']=list()
    playlist_dict['playlist_name']=list()
    # # Extract and print playlist information
    if len(response["items"]) > 0:
        for index,item in enumerate(response["items"]):
            playlist_dict['channel_id'].append(item['snippet']['channelId'])
            playlist_dict['playlist_id'].append(item["id"])
            playlist_dict['playlist_name'].append(item['snippet']["localized"]["title"])
            # print(f"Channel ID:{channel_id}, Playlist ID: {playlist_id}, Title: {title}")
    else:
        print("No playlists found for the channel.")

    #Creating a dataframe for the playlist dictionary
    playlist_df=pd.DataFrame(playlist_dict)
    # print(playlist_df)
    return playlist_df, playlist_dict['playlist_id']

if __name__ == "__main__":
    playlist_details(API_KEY, CHANNEL_ID)

# %%
playlist_df,playlist_lst=playlist_details(API_KEY,CHANNEL_ID)

# %%
playlist_lst
# Out:
# ['PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3',
#  'PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo',
#  'PL8Q-CmKVRc9rBKxXKNJ8AZvO76gPwMt5j',
#  'PL8Q-CmKVRc9rixGG5rvrQjeb5Sr3aDhRB',
#  'PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i',
#  'PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww',
#  'PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O',
#  'PL8Q-CmKVRc9rmmeVoM4Tsv1BcOiRN7-qE',
#  'PL8Q-CmKVRc9rXKnOEhQYE-NZfuezGgSj8',
#  'PL8Q-CmKVRc9og3lz59j09jMxjClYrs4dJ',
#  'PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv']

# %%
import googleapiclient.discovery
import pandas as pd
# from utils.playlist import playlist_details

# Define the maximum number of videos to retrieve (optional)
MAX_RESULTS = 500


def video_details(API_KEY, PLAYLIST_LST):
    # Define the YouTube service object
    youtube = googleapiclient.discovery.build(
     "youtube", "v3", developerKey=API_KEY
    )
    # Creating a dictionary and setting up its structure
    video_dict=dict()
    video_dict['video_id']=list()
    video_dict['playlist_id']=list()
    video_dict['video_name']=list()
    video_dict['video_description']=list()
    video_dict['published_date']=list()
    video_dict['duration']=list()

    #Looping through each of the playlist id
    for PLAYLIST_ID in PLAYLIST_LST:

        # Define the request parameters
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=PLAYLIST_ID,
            maxResults=MAX_RESULTS
        )

        # Execute the request and get the response
        response = request.execute()
        # pprint.pprint(response)
        
        print(f'The response for playlist id : {PLAYLIST_ID}')
        print(response)
        # Extract and print video information
        if len(response["items"]) > 0:
            for item in response["items"]:
                video_dict['video_id'].append(item["snippet"]["resourceId"]["videoId"])   
                video_dict['playlist_id'].append(item["snippet"]["playlistId"])
                video_dict['video_name'].append(item["snippet"]["title"])
                video_dict['video_description'].append(item["snippet"]["description"])
                video_dict['published_date'].append(item["snippet"]["publishedAt"])
                duration = item["contentDetails"].get("duration")
                # Handle cases where duration might be missing
                if duration:
                    video_dict['duration'].append(duration)
                else:
                    video_dict['duration'].append('no duration available')

                # You can access other video details from the response as needed:
                # - thumbnails: item["snippet"]["thumbnails"] (dictionary with thumbnail URLs)
                # - publishTime: item["snippet"]["publishedAt"]

                # print(f"Video ID: {video_id}, Playlist ID:{playlist_id}, Video Name:{video_name}, Video Description:{video_description}, Published Date:{published_date}, Duration:{duration}")
        else:
            print(f"No videos found in the playlist - {PLAYLIST_ID}")

    video_df=pd.DataFrame(video_dict)
    video_df['published_date']=pd.to_datetime(video_df['published_date'])
    video_df['published_date'] = video_df['published_date'].dt.strftime('%Y-%m-%d %H:%M:%S')
    return video_df, video_dict['video_id']

# if __name__ == "__main__":
#     video_details(API_KEY, PLAYLIST_LST)

# %%
playlist_lst
# Out:
# ['PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3',
#  'PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo',
#  'PL8Q-CmKVRc9rBKxXKNJ8AZvO76gPwMt5j',
#  'PL8Q-CmKVRc9rixGG5rvrQjeb5Sr3aDhRB',
#  'PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i',
#  'PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww',
#  'PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O',
#  'PL8Q-CmKVRc9rmmeVoM4Tsv1BcOiRN7-qE',
#  'PL8Q-CmKVRc9rXKnOEhQYE-NZfuezGgSj8',
#  'PL8Q-CmKVRc9og3lz59j09jMxjClYrs4dJ',
#  'PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv']

# %%
video_df, video_lst=video_details(API_KEY,playlist_lst)
# Out:
# The response for playlist id : PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# ...

# %%
video_df
# Out:
#         video_id                         playlist_id  \
# 0    kYyqBV1QxgM  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 1    sNTflzAbiXw  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 2    mX00gZz3A0w  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 3    XZl1J0jDCJE  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 4    iAwU9gdexUs  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# ..           ...                                 ...
# 160  cAaecKfqfoc  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 161  SaAxYkhyLKs  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 162  UZBr0pKHRt8  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 163  JmUjUE9hY0U  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 164  xefkwX7ST-o  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
#
#                                             video_name  \
# 0    Behaviour issues in Autism😣 | Sensory Processi...
# 1    Behaviour management at home👌 - Tactile dysfun...
# 2    Behaviour issues in Autism😣 | 10 Activities to...
# 3    Behaviour issues in Autism😣 | Sensory Processi...
# ...

# %%
duplicate_rows=video_df[video_df.duplicated('video_id')]
print(duplicate_rows)
print('No. of duplicate rows present : ',len(duplicate_rows))
# Out:
#         video_id                         playlist_id  \
# 51   9RzIQICxmYo  PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i
# 53   Qw6NWmUkTuc  PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i
# 54   xqZwTVAIRn4  PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i
# 79   EiOX9zTkhj8  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 105  rDClsLM_NDY  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 106  5QyH-3atKPM  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 107  WhmsnnHI4_U  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 109  23b-p-BeYsE  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 111  UF2-J4wlgDk  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 112  d0D6vvanlns  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 114  ocCDaneFaeE  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 115  IMH0RqNZYKc  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 116  zZuLuoB1B4s  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 117  fj_Oq478ts8  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 118  9RzIQICxmYo  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 119  SAvtGNs68F8  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# 122  -PGLrwPLFYI  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
# ...

# %%
video_df[video_df['video_id']=='9RzIQICxmYo']
# Out:
#         video_id                         playlist_id  \
# 8    9RzIQICxmYo  PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo
# 51   9RzIQICxmYo  PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i
# 118  9RzIQICxmYo  PL8Q-CmKVRc9pbC1fC4hnwHxN6MzX04r1O
#
#                                             video_name  \
# 8    Connect Your Child with surroundings | Teachin...
# 51   Connect Your Child with surroundings | Teachin...
# 118  Connect Your Child with surroundings | Teachin...
#
#                                      video_description       published_date  \
# 8    "No one else can do, what the Parents can do f...  2023-09-16 15:06:50
# 51   "No one else can do, what the Parents can do f...  2023-03-21 07:23:36
# 118  "No one else can do, what the Parents can do f...  2022-08-22 15:13:44
#
#                   duration
# 8    no duration available
# 51   no duration available
# 118  no duration available

# %%
len(video_df)
# Out:
# 165

# %%
video_df_without_duplicates=video_df.drop_duplicates(subset=['video_id'])

# %%
video_df_without_duplicates
# Out:
#         video_id                         playlist_id  \
# 0    kYyqBV1QxgM  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 1    sNTflzAbiXw  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 2    mX00gZz3A0w  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 3    XZl1J0jDCJE  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 4    iAwU9gdexUs  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# ..           ...                                 ...
# 160  cAaecKfqfoc  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 161  SaAxYkhyLKs  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 162  UZBr0pKHRt8  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 163  JmUjUE9hY0U  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 164  xefkwX7ST-o  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
#
#                                             video_name  \
# 0    Behaviour issues in Autism😣 | Sensory Processi...
# 1    Behaviour management at home👌 - Tactile dysfun...
# 2    Behaviour issues in Autism😣 | 10 Activities to...
# 3    Behaviour issues in Autism😣 | Sensory Processi...
# ...

# %%
import pandas as pd

# %%
video_df=pd.read_csv('D:\\Saravanesh Personal\\Guvi\\Capstone Projects\\Youtube Data Harvesting\\process_dataframe\\video.csv')

# %%
video_df
# Out:
#         video_id                         playlist_id  \
# 0    kYyqBV1QxgM  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 1    sNTflzAbiXw  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 2    mX00gZz3A0w  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 3    XZl1J0jDCJE  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# 4    iAwU9gdexUs  PL8Q-CmKVRc9r8qQEBhDrxAWxVn0A5YuX3
# ..           ...                                 ...
# 140  SaAxYkhyLKs  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 141  UZBr0pKHRt8  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 142  JmUjUE9hY0U  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 143  xefkwX7ST-o  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
# 144  4lg6R6TIeqE  PL8Q-CmKVRc9rV4xW4edHVi8QKKOLqPNyv
#
#                                             video_name  \
# 0    Behaviour issues in Autism😣 | Sensory Processi...
# 1    Behaviour management at home👌 - Tactile dysfun...
# 2    Behaviour issues in Autism😣 | 10 Activities to...
# 3    Behaviour issues in Autism😣 | Sensory Processi...
# ...

# %%
video_df[video_df.isna().any(axis=1)]['duration']
# Out:
# 16    NaN
# 23    NaN
# 24    NaN
# 26    NaN
# 28    NaN
# 40    NaN
# 45    NaN
# 52    NaN
# 53    NaN
# 54    NaN
# 55    NaN
# 56    NaN
# 57    NaN
# 58    NaN
# 59    NaN
# 60    NaN
# 61    NaN
# 62    NaN
# 63    NaN
# 64    NaN
# 65    NaN
# 66    NaN
# 67    NaN
# 68    NaN
# 69    NaN
# 70    NaN
# 71    NaN
# 73    NaN
# 74    NaN
# 75    NaN
# 76    NaN
# 77    NaN
# 79    NaN
# 80    NaN
# 81    NaN
# 82    NaN
# 83    NaN
# 84    NaN
# 85    NaN
# 86    NaN
# 87    NaN
# 88    NaN
# 89    NaN
# 90    NaN
# 92    NaN
# 93    NaN
# 95    NaN
# 96    NaN
# 99    NaN
# 100   NaN
# 102   NaN
# 104   NaN
# 105   NaN
# 116   NaN
# 117   NaN
# Name: duration, dtype: float64

# %%
nan_duration_rows=video_df['duration'].isna()

# %%
len(nan_duration_rows)
# Out:
# 145

# %%
video_df.loc[nan_duration_rows,'duration']=0

# %%
video_df[video_df['duration'].isna()]
# Out:
# Empty DataFrame
# Columns: [video_id, playlist_id, video_name, video_description, view_count, like_count, dislike_count, favorite_count, comment_count, thumbnail, published_date, duration]
# Index: []

# %%
video_df[video_df['duration']==0]
# Out:
#         video_id                         playlist_id  \
# 16   wLV9PF7WA9s  PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo
# 23   r89wdULt8IM  PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo
# 24   _kNrrFITwac  PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo
# 26   BkIBCkv372M  PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo
# 28   UsImT5M-LbE  PL8Q-CmKVRc9pTiHiAfj7zzzwjm0TePERo
# 40   EiOX9zTkhj8  PL8Q-CmKVRc9rixGG5rvrQjeb5Sr3aDhRB
# 45   23b-p-BeYsE  PL8Q-CmKVRc9pnNuEfQ7QF0YgubNL2_39i
# 52   mVzxJWp0Grc  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 53   vBA4Wtyq5G8  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 54   83mQfja9yzs  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 55   e_DFSlY-gro  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 56   4P2KChXSzRs  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 57   Zk2fo05oBpY  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 58   BvX5ajaaipU  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 59   I462lJrQSQo  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 60   xEBu7eulmcA  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# 61   KNxA31kDIJs  PL8Q-CmKVRc9q9FFNF2cXScWjgsTcc0_Ww
# ...

# %%
len(video_df)
# Out:
# 145
